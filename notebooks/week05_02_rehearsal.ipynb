# %% [markdown]
# # Week 5, Day 2: Practicum Rehearsal
#
# ## Today
#
# By the end of this session your pair will be able to:
#
# - Turn a colleague's one-paragraph request into a four-part paper design: restatement, inputs and outputs, decomposition, pseudocode.
# - Interrogate two inputs with `Describe` and `GetCount` before trusting them
# - Find a geoprocessing tool you've never used in ArcGIS Pro's tool reference, read its Syntax block, and write the arcpy call yourself.
# - Explain why the number of features a tool writes out is not always the number of things you asked about.
#
# Today is an **ungraded** rehearsal for Practicum 1, with the same rules as the real thing: paired, no AI assistants of any kind; documentation, notes, and your own course notebooks are all allowed

# %% [markdown]
# ## The request
#
# > "The county is reviewing its riparian buffer rules. Before the meeting I need to know how many of Portage County's mapped wetlands actually sit on a river, and how many are within some distance of one. Can you get me numbers?"
#
# Two inputs can be found the repository's `variety` folder: `portage_wetlands.shp` and `neohio_rivers.shp`. Your pair's **card** sets "some distance."
#
# Stated formally: **count the wetlands that a river actually crosses; then, separately, count the wetlands that lie within your card's distance of a river.**

# %% [markdown]
# ## Step 1: design on paper (20 minutes, no computer)
#
# Before you touch the keyboard or any Python, produce the four-part artifact on paper with your partner, both sign it, and photograph it. Your are implementing *your* design.
#
# Two decisions belong on the paper, not in the code:
#
# - The tools you already know (`Buffer`, `Describe`, `GetCount`) don't answer "which wetlands touch a river" on their own. You will need to figure out the *kind* of operation you need.
# - "How many wetlands" and "how many output features" are not always the same number. Write down how you'll tell which one your code is counting.

# %% [markdown]
# ## Step 2: which wetlands does a river actually cross?
#
# This is the operation you identified on paper. You need a tool that takes the wetlands and the rivers and produces the places where they coincide.
#
# **The look-up, on your own:** search the tool in the Geoprocessing pane, click **Learn more**, and read the **Syntax** block on its reference page. Three questions to answer from the page before you write anything:
#
# 1. What does the first parameter expect: one feature class, or a list of them?
# 2. Which parameters are required, and which are optional?
# 3. What geometry type will the output have when one input is polygons and the other is lines?
#
# Then write the call, with a workspace-relative output name of your choosing, and print `GetCount` of the output.

# %%
pass  # your code here

# %% [markdown]
# ## Step 3: how far is "near"? Which wetlands are within the "near" distance?
#
# Your index card's distance defines "near a river." Perform a spatial operation (as designed) to answer the question.
#
# Read the Syntax block again if you switch tools. Clip and the step 2 tool take their inputs in different shapes.

# %% [markdown]
# 🔮 **Predict before you run:** guess what `GetCount` on your buffer output reports for the `dissolve_option` you chose. With the other choice, what would it report instead?

# %%
pass  # your code here

# %% [markdown]
# ## Step 4 (stretch goal): how much wetland is that?
#
# `portage_wetlands.shp` contains an `acres` field. Sum it over the output with a `SearchCursor`, week 4's pattern, and report total acreage of the wetlands that come within your card's distance of a river.

# %%
pass  # your code here
