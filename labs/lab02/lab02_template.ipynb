# %% [markdown]
# # Lab 2 Template: Batch Geoprocessing and Data Interrogation
#
# **How to use this template:** this notebook has one markdown header and one seeded code (or answer) cell for every graded task in `lab02.qmd`, in order. Task B assumes Task A's workspace setup, and Task C requires both, so work through the notebook top to bottom. Replace each `pass` placeholder (or placeholder text) with your real code or answer, adding extra cells if you need scratch work, but keep the seeded cell as your final answer for that task. Save this notebook in sensible location, alongside the lab's data files, and run it top to bottom before you submit.

# %% [markdown]
# ## Task A: Inventory script (22 points)

# %%
# Task A: your code here
pass

# %% [markdown]
# ## Task B: Batch buffer (30 points)

# %% [markdown]
# _Your two chosen buffer distances and why, in one sentence:_

# %%
# Task B: your code here
pass

# %% [markdown]
# ## Task C: Interrogation memo (19 points)

# %% [markdown]
# ### Task C.1: Which feature class has the most features?

# %%
# Task C.1: your code here
pass

# %% [markdown]
# ### Task C.2: Which feature classes share a CRS, and which differs?

# %%
# Task C.2: your code here
pass

# %% [markdown]
# ### Task C.3: Which feature class has the most total fields, and which the fewest?

# %%
# Task C.3: your code here
pass

# %% [markdown]
# ### Task C.4: Is `streams_portage.geojson` in `ListFeatureClasses()`?

# %%
# Task C.4: your code here
pass

# %% [markdown]
# ### Task C.5: Do all three feature classes have a field named exactly `NAME`?

# %%
# Task C.5: your code here
pass

# %% [markdown]
# ### Task C: memo

# %% [markdown]
# _Your 3-5 sentence memo here, synthesizing what you found across all five questions._
