# %% [markdown]
# # Lab 3 Template
#
# **How to use this template:** this notebook has one markdown header and one seeded code (or answer) cell for every graded task in `lab03.qmd`. The setup's new GeoPackage feeds Task A's inventory and Task B's required differences, so work through the notebook top to bottom. Replace each `pass` placeholder (or placeholder text) with your code or answer, adding extra cells above/below if you need scratch work, but keep the seeded cell as the one that holds your final answer for that task. Run the notebook top to bottom before you submit.

# %% [markdown]
# ## Setup: growing the case file

# %%
# Setup -- workspace, overwrite, and the new item (counties_pro.gpkg)
pass

# %% [markdown]
# ## Task A: Programmatic inventory (19 points)

# %%
# Task A -- your code here
pass

# %% [markdown]
# ## Task B: The differences hunt (23 points)

# %% [markdown]
# ### Task B.1: The ten-character wall

# %%
# Task B.1 -- your code here
pass

# %% [markdown]
# _Your one-or-two-sentence interpretation of B.1 here: what is the shapefile version's field name, and why?_

# %% [markdown]
# ### Task B.2: Two GeoPackages, two different primary-key names

# %%
# Task B.2 -- your code here
pass

# %% [markdown]
# _Your one-sentence interpretation of B.2 here: why don't the two names match?_

# %% [markdown]
# ### Task B.3: Your own third difference

# %%
# Task B.3 -- your code here
pass

# %% [markdown]
# _Your one-or-two-sentence interpretation of B.3 here: what's the difference, and what does it mean?_

# %% [markdown]
# ## Task C: Standardize (19 points)

# %%
# Task C -- your code here (one canonical copy, written into standardized/)
pass

# %% [markdown]
# _Your 4-6 sentence justification here: what you're optimizing for, and what you're giving up by not picking one of the other four formats._

# %% [markdown]
# ## Task D: Recommendation memo (10 points)

# %% [markdown]
# _Your memo here, 300 words or fewer. Ground each in something you actually observed this lab._
