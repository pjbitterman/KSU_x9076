# %% [markdown]
# # Lab 1 Template — Python Fundamentals and Your First Automation
#
# **How to use this template:** this notebook has one markdown header and one seeded code (or answer) cell for every graded task in `lab01.qmd`, in order. Do all of your work inside the matching cell — replace the `pass` placeholder (or the placeholder text) with your real code or answer, and add extra cells above/below it if you need scratch work, but keep the seeded cell as the one that holds your final answer for that task. Save this notebook in the same folder as `ohio_precip_2025.csv` and `ohio_counties.shp` (`C:/geog9076/act1/`), and run it top to bottom before you submit to make sure it's runnable start to finish.

# %% [markdown]
# ## Part 1: Python Fundamentals

# %% [markdown]
# ### Task 1.1 — Count, min, max, mean (7 points)

# %%
# Task 1.1 -- your code here
pass

# %% [markdown]
# ### Task 1.2 — Stations above the mean (7 points)

# %%
# Task 1.2 -- your code here
pass

# %% [markdown]
# ### Task 1.3 — A conversion function (21 points)

# %%
# Task 1.3 -- your code here
pass

# %% [markdown]
# ## Part 2: One Tool, Three Ways — Buffer and Summarize

# %% [markdown]
# ### Task 2.1 — ModelBuilder (16 points)

# %% [markdown]
# _Task 2.1 is submitted as two screenshots through Canvas, not as notebook cells — build and run the model in ModelBuilder, then attach the screenshots to your Canvas submission alongside this notebook._

# %%
# Task 2.1 -- ModelBuilder screenshots are submitted separately in Canvas, not in this notebook.
pass

# %% [markdown]
# ### Task 2.2 — arcpy (12 points)

# %%
# Task 2.2 -- your code here
pass

# %% [markdown]
# ### Task 2.3 — Prose (8 points)

# %% [markdown]
# _Your 3–5 sentence answer here: for this specific two-step workflow, when would you reach for the GUI dialog, when for ModelBuilder, and when for `arcpy`?_
